# %% [markdown]
# # Exam Mark Prediction

# %% [markdown]
# ## Linear Regression - using Multiple variables

# %% [markdown]
# **In this project we are going to use Linear Regression Algorithm to predict the Marks scored by a student based on the Number of Courses and the Study Time of the student that is provided.**

# %%
# Importing the libraries
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# Load the dataset
dataset = pd.read_csv("Student_Marks.csv")
dataset.head()
# Out:
#    number_courses  time_study   Marks
# 0               3       4.508  19.202
# 1               4       0.096   7.734
# 2               4       3.133  13.811
# 3               6       7.909  53.018
# 4               8       7.811  55.299

# %%
# Extract the shape of the dataset to find the rows and columns
print(dataset.shape)
# Out:
# (100, 3)

# %%
# Finding null values from features x
dataset.columns[dataset.isna().any()]
# Out:
# Index(['time_study'], dtype='object')

# %%
# Removing null values from features X
dataset.time_study = dataset.time_study.fillna(dataset.time_study.mean())
dataset
# Out:
#     number_courses  time_study   Marks
# 0                3       4.508  19.202
# 1                4       0.096   7.734
# 2                4       3.133  13.811
# 3                6       7.909  53.018
# 4                8       7.811  55.299
# ..             ...         ...     ...
# 95               6       3.561  19.128
# 96               3       0.301   5.609
# 97               4       7.163  41.444
# 98               7       0.309  12.027
# 99               3       6.335  32.357
#
# [100 rows x 3 columns]

# %%
# Segregate Dataset into input x and output y
x = dataset.iloc[:,:-1].values
y = dataset.iloc[:,-1].values

# %%
# Data Visualization using Matplotlib
x1 = dataset.iloc[:,0].values
x2 = dataset.iloc[:,1].values
a = plt.subplot()
a.plot(x1,y,label="number_courses")
a.plot(x2,y,label="time_study")
plt.legend()
plt.show()

# %%
# Data Visulaization using Seaborn
sns.pairplot(dataset)

# %%
# Split the data for training and testing
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3,random_state=0)

# %%
# Shape of the train and test sets
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (70, 2)
# (30, 2)
# (70,)
# (30,)

# %%
# Train the algorithm
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Predicting the test set results
x_val = [[2,5.999]]
y_pred = model.predict(x_val)
print(y_pred)
# Out:
# [28.95408619]

# %%
# Calculating the accuracy of the model
r2_score = model.score(x_train, y_train)
print(r2_score*100,'%')
# Out:
# 93.78771069749018 %
